# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# %%
#Answer1
df = pd.read_csv("WA_-HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#Answer1(a)
categorical = df.select_dtypes(include=['object']).columns.tolist()
numerical = df.select_dtypes(include=['number']).columns.tolist()
print('categorical')
print(categorical)
print('numerical')
print(numerical)
# Out:
# categorical
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# numerical
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
#Answer2(a)
print('I  dropped the EmployeeNumber because this is a unique identifer and this is of no use in the data because of unique values')
df=pd.read_csv("WA_-HR-Employee-Attrition.csv")
df=df.drop(labels=['EmployeeNumber'],axis=1)
df.head(10)
# Out:
# I  dropped the EmployeeNumber because this is a unique identifer and this is of no use in the data because of unique values
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#Answee2(b)
print("I  drop the EmployeeCount because of this same value which is 1")
df=df.drop(labels=['EmployeeCount'],axis=1)
df.head(10)
# Out:
# I  drop the EmployeeCount because of this same value which is 1
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %%
#Answer3(a)
categorical=df.select_dtypes(include=['object']).columns.tolist()
df=df.drop(columns=cat,axis=1)
variance = VarianceThreshold(threshold=0)
df.head(10)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41       1102                 1          2              1
# 1   49        279                 8          1              1
# 2   37       1373                 2          2              1
# 3   33       1392                 3          4              1
# 4   27        591                 2          1              1
# 5   32       1005                 2          2              1
# 6   59       1324                 3          3              1
# 7   30       1358                24          1              1
# 8   38        216                23          3              1
# 9   36       1299                27          3              1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# ...

# %%
#Answer3(B)
constant=[column for column in df.columns if column not in df.columns[var.get_support()]]
print(constant)
# Out:
# ['EmployeeCount', 'StandardHours']

# %%
#Answer4(a)
df.columns[var.get_support()]
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df = df.drop(constant,axis=1)
df.head(15)
# Out:
#     Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0    41       1102                 1          2                        2
# 1    49        279                 8          1                        3
# 2    37       1373                 2          2                        4
# 3    33       1392                 3          4                        4
# 4    27        591                 2          1                        1
# 5    32       1005                 2          2                        4
# 6    59       1324                 3          3                        3
# 7    30       1358                24          1                        4
# 8    38        216                23          3                        4
# 9    36       1299                27          3                        3
# 10   35        809                16          3                        1
# 11   29        153                15          2                        4
# ...

# %%
df.shape
# Out:
# (1470, 23)

# %%
#Answer5(a)
df = pd.read_csv('WA_-HR-Employee-Attrition.csv')
df =df.drop(labels=['EmployeeNumber'],axis=1)
df = df.drop(labels=['EmployeeCount'],axis=1)
cat = df.select_dtypes(include=['object']).columns.tolist()
df = df.drop(columns=cat,axis=1)
var = VarianceThreshold(threshold=0.01)
var.fit(df)
constant=[column  for column in df.columns if column not in df.columns[var.get_support()]]
print("The constant column when then the threshold is 0.01 is",constant)
df=df.drop(constant,axis=1)
df.head(10)
# Out:
# The constant column when then the threshold is 0.01 is ['StandardHours']
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
# 5   32       1005                 2          2                        4
# 6   59       1324                 3          3                        3
# 7   30       1358                24          1                        4
# 8   38        216                23          3                        4
# 9   36       1299                27          3                        3
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# ...

# %%
#Answer5(b)
print("After dropping the constant column based on the threshold value of 0 and 0.01 both  the same ")
# Out:
# After dropping the constant column based on the threshold value of 0 and 0.01 both  the same
